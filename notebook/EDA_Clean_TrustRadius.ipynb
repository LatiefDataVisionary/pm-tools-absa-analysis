# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pm-tools-absa-analysis/blob/main/notebook/EDA_Clean_TrustRadius.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
trello_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/trustradius/trustradius_trello_reviews.csv')
jira_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/trustradius/trustradius_jira_reviews.csv')
clickup_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/trustradius/trustradius_clickup_reviews.csv')

# %%
trello_df.head(10)
# Out:
#   product_name                                       review_title  rating  \
# 0       Trello                              Exceeded expectations     NaN
# 1       Trello             Trello for task management is the BEST     NaN
# 2       Trello                Trello - decent for task management     NaN
# 3       Trello                  Trello Review from HR Perspective     NaN
# 4       Trello      Trello an intuitive way to organize your work     NaN
# 5       Trello  Effective at Managing Onboarding Could be Less...     NaN
# 6       Trello                           Trello Great Launch Pad.     NaN
# 7       Trello                         My experience with Trello.     NaN
# 8       Trello    Trello is the life savor for project management     NaN
# 9       Trello  Trello is definitely best suited for a work se...     NaN
#
#                                                 pros  \
# 0  Tasks overviewTracking updatesTeam follow upWe...
# 1                                                NaN
# 2  Process flow visibilitykeeping information fro...
# 3       Organization of tasksTimeframesCustomization
# 4  Organize tasksCheck project statusMonitor acti...
# 5  Different forms of communicationEngaging, aest...
# 6  RolloutPost rollout evaluation.Team coordination.
# 7  Allows you to create cards for specific tasks....
# 8  Project ManagementResource ManagementCollabora...
# 9    OrganizationLabelingAllows attachments to tasks
#
#                                                 cons  \
# 0  More customizationChat notificationsReminder m...
# 1  I wish that you could click a button and creat...
# 2                                                NaN
# 3  Needs more advanced project management functio...
# 4  Overall site performanceImprove security. Duri...
# 5  It’d be nice for an admin to put a limit of ho...
# 6                            AlertsTracking changes.
# 7  I use colour coding a lot so I would like a wi...
# 8  Trello Lacks comprehensive reporting. Even wit...
# 9                   Categories inside the categories
#
#                                         full_content  page_number
# 0  Exceeded expectationsRating: 10 out of 10Incen...            1
# 1  Trello for task management is the BESTRating: ...            1
# 2  Trello - decent for task managementRating: 8 o...            1
# 3  Trello Review from HR PerspectiveRating: 9 out...            1
# 4  Trello an intuitive way to organize your workR...            1
# 5  Effective at Managing Onboarding Could be Less...            1
# 6  Trello Great Launch Pad.Rating: 10 out of 10In...            1
# 7  My experience with Trello.Rating: 10 out of 10...            1
# 8  Trello is the life savor for project managemen...            1
# 9  Trello is definitely best suited for a work se...            1

# %%
jira_df.head(10)
# Out:
#   product_name                                       review_title  rating  \
# 0         Jira    Best tool for track and manage the project work     NaN
# 1         Jira  Great tool for enterprises for project and res...     NaN
# 2         Jira                       Good tool to manage projects     NaN
# 3         Jira                             A Tool Must Have By PM     NaN
# 4         Jira  Great tool for team organization and collabora...     NaN
# 5         Jira         A must have for product backlog management     NaN
# 6         Jira     Jira A Software for Streamlining IT Operations     NaN
# 7         Jira    Atlassian Jira - Good workflow  project manager     NaN
# 8         Jira  Using Jira for handling customer support and t...     NaN
# 9         Jira  Awesome feature set with a sometimes challengi...     NaN
#
#                                                 pros  \
# 0  Atlassian Jira is very good at managing and tr...
# 1  Project ManagementResource ManagementDashboard...
# 2  Create and manage work itemsKeep track of over...
# 3  Bug TrackingResource ManagementFriedly User In...
# 4  Organizing sprintsDescribing and tracking task...
# 5  Product backlog managementProgram managementPo...
# 6  The ticket can be classified according to the ...
# 7  Its holds data in very structured wayvery good...
# 8  Allow for customizable workflows.Issue trackin...
# 9  Visualizing ongoing work.Enabling team plannin...
#
#                                                 cons  \
# 0  Atlassian Jira has many features which can mak...
# 1                 Searching issues can be simplified
# 2  Associate Salesforce ultant in Information Tec...
# 3        Time LoggingSprint ManagaementGenerative AI
# 4    Navigation, e.g. to WikiCustomizable dashborrds
# 5  Dependencies listingDocumentation managementTe...
# 6  When I was making a new component for an incid...
# 7  UI looks can be much betterUsers management ca...
# 8  Support on configuration.Eazy BI.Reporting cus...
# 9  Interface is sometimes clunky or not exactly u...
#
#                                         full_content  page_number
# 0  Best tool for track and manage the project wor...            1
# 1  Great tool for enterprises for project and res...            1
# 2  Good tool to manage projectsRating: 9 out of 1...            1
# 3  A Tool Must Have By PMRating: 9 out of 10Incen...            1
# 4  Great tool for team organization and collabora...            1
# 5  A must have for product backlog managementRati...            1
# 6  Jira A Software for Streamlining IT Operations...            1
# 7  Atlassian Jira - Good workflow  project manage...            1
# 8  Using Jira for handling customer support and t...            1
# 9  Awesome feature set with a sometimes challengi...            1

# %%
clickup_df.head(10)
# Out:
#   product_name                                       review_title  rating  \
# 0      ClickUp                                                NaN     NaN
# 1      ClickUp                                                NaN     NaN
# 2      ClickUp                                                NaN     NaN
# 3      ClickUp                Consolidate Platforms Using ClickUp     NaN
# 4      ClickUp                        My experience with ClickUp.     NaN
# 5      ClickUp                           ClickUp is our team hero     NaN
# 6      ClickUp           All in one software management - Clickup     NaN
# 7      ClickUp                               Absolutely Fantastic     NaN
# 8      ClickUp  ClickUp A Useful Tool for Multi-Department Org...     NaN
# 9      ClickUp                                    Best Tool I Use     NaN
#
#                                                 pros  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  Tracking email communications externally per c...
# 4                     AutomationsWorkspacesTemplates
# 5  DashboardsCustomized FieldsFolder/Space Organi...
# 6  tracking of taskassign new taskautomation through
# 7  Keeps track of due dates for projectsKeep trac...
# 8  Task movement using Groups on SpacesClips to v...
# 9  automationstask creationtimeline managementpro...
#
#                                                 cons  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  The AI synthesizing cannot parse through large...
# 4                           AutomationsFormulasDates
# 5                                                NaN
# 6  include more option in automationdashboardsome...
# 7              I would prefer a non black background
# 8  Main search bar is very glitchySetting up noti...
# 9  lag timemore opportunities for data collection...
#
#                                         full_content  page_number
# 0  User Review: Click Up Allows A Simple & Clear ...            1
# 1  ClickUp Aids In Delegating Out Tasks To Team M...            1
# 2  ClickUp Review: Enables Accountability Between...            1
# 3  Consolidate Platforms Using ClickUpRating: 7 o...            1
# 4  My experience with ClickUp.Rating: 10 out of 1...            1
# 5  ClickUp is our team heroRating: 8 out of 10Inc...            1
# 6  All in one software management - ClickupRating...            1
# 7  Absolutely FantasticRating: 10 out of 10Incent...            1
# 8  ClickUp A Useful Tool for Multi-Department Org...            1
# 9  Best Tool I UseRating: 10 out of 10Incentivize...            1

# %%
trello_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  222 non-null    object
#  1   review_title  222 non-null    object
#  2   rating        0 non-null      float64
#  3   pros          196 non-null    object
#  4   cons          206 non-null    object
#  5   full_content  222 non-null    object
#  6   page_number   222 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 12.3+ KB

# %%
jira_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  223 non-null    object
#  1   review_title  223 non-null    object
#  2   rating        0 non-null      float64
#  3   pros          199 non-null    object
#  4   cons          202 non-null    object
#  5   full_content  223 non-null    object
#  6   page_number   223 non-null    int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 12.3+ KB

# %%
clickup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   product_name  1293 non-null   object
#  1   review_title  717 non-null    object
#  2   rating        0 non-null      float64
#  3   pros          690 non-null    object
#  4   cons          672 non-null    object
#  5   full_content  1293 non-null   object
#  6   page_number   1293 non-null   int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 70.8+ KB

# %%
trello_df['full_content']
# Out:
# 0      Exceeded expectationsRating: 10 out of 10Incen...
# 1      Trello for task management is the BESTRating: ...
# 2      Trello - decent for task managementRating: 8 o...
# 3      Trello Review from HR PerspectiveRating: 9 out...
# 4      Trello an intuitive way to organize your workR...
#                              ...
# 217    Great Card Based Project ManagementRating: 8 o...
# 218    Trello from an HR / business standpointRating:...
# 219    Trello: good for small agile teamsRating: 8 ou...
# 220    I couldn't function without my Trello boardsRa...
# 221    Trello perfect for simple task management and ...
# Name: full_content, Length: 222, dtype: object

# %%
jira_df['full_content']
# Out:
# 0      Best tool for track and manage the project wor...
# 1      Great tool for enterprises for project and res...
# 2      Good tool to manage projectsRating: 9 out of 1...
# 3      A Tool Must Have By PMRating: 9 out of 10Incen...
# 4      Great tool for team organization and collabora...
#                              ...
# 218    Good bug and project tracking tool, but could ...
# 219    Great Product for AgileRating: 10 out of 10Inc...
# 220    My 2 cents on Atlassian JiraRating: 8 out of 1...
# 221    JIRA GreenHopperRating: 6 out of 10Incentivize...
# 222    A great Scrum-oriented ticketing systemRating:...
# Name: full_content, Length: 223, dtype: object

# %%
clickup_df['full_content']
# Out:
# 0       User Review: Click Up Allows A Simple & Clear ...
# 1       ClickUp Aids In Delegating Out Tasks To Team M...
# 2       ClickUp Review: Enables Accountability Between...
# 3       Consolidate Platforms Using ClickUpRating: 7 o...
# 4       My experience with ClickUp.Rating: 10 out of 1...
#                               ...
# 1288    User Review: Click Up Allows A Simple & Clear ...
# 1289    ClickUp Aids In Delegating Out Tasks To Team M...
# 1290    ClickUp Review: Enables Accountability Between...
# 1291    ClickUp Review: Works To Effectively Keep Coll...
# 1292    ClickUp Allows Project Status To Be Monitored ...
# Name: full_content, Length: 1293, dtype: object

# %%
dataframes = {
    "trello_df": trello_df,
    "jira_df": jira_df,
    "clickup_df": clickup_df
}

for df_name, df in dataframes.items():
    print(f"--- Null Information for {df_name} ---")
    null_counts = df.isnull().sum()
    null_percentages = (null_counts / len(df)) * 100

    null_info_df = pd.DataFrame({
        'Null Count': null_counts,
        'Null Percentage': null_percentages.round(2)
    })
    print(null_info_df)
    print("\n")
# Out:
# --- Null Information for trello_df ---
#               Null Count  Null Percentage
# product_name           0             0.00
# review_title           0             0.00
# rating               222           100.00
# pros                  26            11.71
# cons                  16             7.21
# full_content           0             0.00
# page_number            0             0.00
#
#
# --- Null Information for jira_df ---
#               Null Count  Null Percentage
# product_name           0             0.00
# review_title           0             0.00
# rating               223           100.00
# pros                  24            10.76
# cons                  21             9.42
# full_content           0             0.00
# page_number            0             0.00
#
#
# --- Null Information for clickup_df ---
#               Null Count  Null Percentage
# product_name           0             0.00
# review_title         576            44.55
# rating              1293           100.00
# pros                 603            46.64
# cons                 621            48.03
# full_content           0             0.00
# page_number            0             0.00

# %%
for df_name, df in dataframes.items():
    print(f"--- Duplicates Information for {df_name} ---")
    duplicate_counts = df.duplicated().sum()
    print(duplicate_counts)
    print("\n")
# Out:
# --- Duplicates Information for trello_df ---
# 0
#
#
# --- Duplicates Information for jira_df ---
# 0
#
#
# --- Duplicates Information for clickup_df ---
# 0

# %% [markdown]
# # Detailed Exploratory Data Analysis (EDA)
# In this section, we will perform a deep dive into the review data for Trello, Jira, and ClickUp.

# %%
import re
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter

def extract_rating(text):
    if not isinstance(text, str): return None
    match = re.search(r'Rating: (\d+) out of 10', text)
    return int(match.group(1)) if match else None

for name, df in dataframes.items():
    # 1. Extract Numeric Rating from text
    df['extracted_rating'] = df['full_content'].apply(extract_rating)

    # 2. Text Length Analysis
    df['review_len'] = df['full_content'].str.len()
    df['word_count'] = df['full_content'].str.split().str.len()

print("Features extracted: extracted_rating, review_len, word_count")
# Out:
# Features extracted: extracted_rating, review_len, word_count

# %% [markdown]
# ### Step 1: Distribution of Extracted Ratings
# Let's see how users are scoring these tools based on the text snippets.

# %%
plt.figure(figsize=(15, 5))
for i, (name, df) in enumerate(dataframes.items()):
    plt.subplot(1, 3, i+1)
    sns.histplot(df['extracted_rating'].dropna(), bins=10, kde=True, color='skyblue')
    plt.title(f'Rating Distribution: {name}')
plt.tight_layout()
plt.show()

for name, df in dataframes.items():
    print(f"\n--- Rating Details for {name} ---")
    rating_counts = df['extracted_rating'].value_counts().sort_index()
    rating_percentages = (df['extracted_rating'].value_counts(normalize=True) * 100).round(2).sort_index()

    rating_table = pd.DataFrame({
        'Rating': rating_counts.index,
        'Count': rating_counts.values,
        'Percentage': rating_percentages.values
    })
    print(rating_table.to_string(index=False))
    print(f"\nAverage rating for {name}: {df['extracted_rating'].mean().round(2)}")
# Out:
# --- Rating Details for trello_df ---
#  Rating  Count  Percentage
#       5      2        0.90
#       6      8        3.60
#       7     21        9.46
#       8     46       20.72
#       9     57       25.68
#      10     88       39.64
#
# Average rating for trello_df: 8.86
#
# --- Rating Details for jira_df ---
#  Rating  Count  Percentage
#       3      1        0.45
#       4      2        0.90
#       5      7        3.14
#       6     12        5.38
#       7     23       10.31
#       8     59       26.46
#       9     65       29.15
#      10     54       24.22
#
# Average rating for jira_df: 8.41
#
# --- Rating Details for clickup_df ---
#  Rating  Count  Percentage
#     1.0      3        0.42
#     3.0      1        0.14
#     4.0      2        0.28
#     5.0      2        0.28
#     6.0      7        0.98
#     7.0     29        4.04
#     8.0     85       11.85
#     9.0    211       29.43
#    10.0    377       52.58
#
# Average rating for clickup_df: 9.23

# %% [markdown]
# ### Step 2: Review Verbosity Analysis
# Are ClickUp users more talkative than Trello users? We analyze the word counts.

# %%
plt.figure(figsize=(12, 6))
plot_data = []
for name, df in dataframes.items():
    temp = df[['word_count']].copy()
    temp['Product'] = name
    plot_data.append(temp)

full_plot_df = pd.concat(plot_data)
sns.boxplot(x='Product', y='word_count', data=full_plot_df)
plt.title('Comparison of Review Word Counts')
plt.yscale('log') # Using log scale if there are huge outliers
plt.show()

print("\n--- Average Word Count per Dataset ---")
for name, df in dataframes.items():
    print(f"Average word count for {name}: {df['word_count'].mean().round(2)}")
# Out:
# --- Average Word Count per Dataset ---
# Average word count for trello_df: 47.87
# Average word count for jira_df: 46.09
# Average word count for clickup_df: 31.63

# %% [markdown]
# ### Step 3: Top Keywords (N-Grams)
# Let's find the most frequent phrases appearing in the 'Pros' and 'Cons' columns to understand user sentiment.

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd # Import pandas here

def get_top_ngram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(n, n), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)

    # Calculate total frequency for percentage calculation
    total_frequency = sum(freq for _, freq in words_freq)

    # Add percentage to each bigram
    words_freq_with_percentage = []
    for word, freq in words_freq[:10]:
        percentage = (freq / total_frequency) * 100 if total_frequency > 0 else 0
        words_freq_with_percentage.append((word, freq, percentage))

    return words_freq_with_percentage

for name, df in dataframes.items():
    print(f"\n--- Top Bigrams for {name} ---")

    print("\nPros:")
    pros_list = df['pros'].dropna()
    if not pros_list.empty:
        top_pros = get_top_ngram(pros_list, 2)
        pros_df = pd.DataFrame(top_pros, columns=['Bigram', 'Frequency', 'Percentage'])
        pros_df['Percentage'] = pros_df['Percentage'].round(2)
        print(pros_df.to_string(index=False))
    else:
        print("No pros data available.")

    print("\nCons:")
    cons_list = df['cons'].dropna()
    if not cons_list.empty:
        top_cons = get_top_ngram(cons_list, 2)
        cons_df = pd.DataFrame(top_cons, columns=['Bigram', 'Frequency', 'Percentage'])
        cons_df['Percentage'] = cons_df['Percentage'].round(2)
        print(cons_df.to_string(index=False))
    else:
        print("No cons data available.")
# Out:
# --- Top Bigrams for trello_df ---
#
# Pros:
#             Bigram  Frequency  Percentage
#           easy use         23        0.81
# project management         14        0.49
#          drag drop         12        0.42
#           ease use          9        0.32
#       team members          8        0.28
#      user friendly          8        0.28
#       assign tasks          8        0.28
#         makes easy          7        0.25
#    task management          7        0.25
#     user interface          6        0.21
#
# Cons:
#             Bigram  Frequency  Percentage
# project management          9        0.33
#       10 employees          6        0.22
#       free version          6        0.22
#        gantt chart          4        0.15
#      time tracking          4        0.15
#             10 001          4        0.15
#      001 employees          4        0.15
#     user interface          4        0.15
#        trello does          4        0.15
#             51 200          4        0.15
#
# --- Top Bigrams for jira_df ---
#
# Pros:
#             Bigram  Frequency  Percentage
# project management         10        0.32
#           easy use          9        0.29
#     atlassian jira          8        0.25
#     issue tracking          6        0.19
#          jira does          6        0.19
#       user stories          6        0.19
#         tools like          4        0.13
#        easy create          4        0.13
#          sub tasks          4        0.13
#       kanban board          4        0.13
#
# Cons:
#                 Bigram  Frequency  Percentage
#         atlassian jira          7        0.24
# information technology          7        0.24
#          user friendly          6        0.21
#          jira software          6        0.21
#                 10 001          6        0.21
#          001 employees          6        0.21
#     ultant information          5        0.17
#                add ons          5        0.17
#         user interface          5        0.17
#                201 500          4        0.14
#
# --- Top Bigrams for clickup_df ---
#
# Pros:
#             Bigram  Frequency  Percentage
#    task management         32        0.43
#      time tracking         23        0.31
# project management         22        0.29
#       team members         19        0.25
#           easy use         19        0.25
#      custom fields         18        0.24
#     tasks projects         12        0.16
#    different views         11        0.15
#     projects tasks         10        0.13
#     user interface         10        0.13
#
# Cons:
#                Bigram  Frequency  Percentage
#            mobile app         25        0.31
#        learning curve         19        0.24
#          10 employees         18        0.22
#         custom fields         14        0.17
#            doesn work          9        0.11
#         time tracking          8        0.10
#          team members          7        0.09
#              new user          7        0.09
# professional services          7        0.09
#             new users          7        0.09

# %% [markdown]
# ### Step 4: Visualizing Word Clouds
# Word clouds provide an immediate visual representation of the most frequent terms used in the reviews.

# %%
plt.figure(figsize=(20, 10))
for i, (name, df) in enumerate(dataframes.items()):
    text = " ".join(review for review in df['full_content'].astype(str))
    wordcloud = WordCloud(background_color='white', max_words=100, width=800, height=400).generate(text)
    plt.subplot(1, 3, i+1)
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.title(f'Word Cloud: {name}')
    plt.axis('off')
plt.show()

# %% [markdown]
# ### Step 5: Sentiment Polarity Analysis
# We use TextBlob to calculate the polarity of each review (ranging from -1 to 1) to understand the underlying emotional tone.

# %%
from textblob import TextBlob

for name, df in dataframes.items():
    df['polarity'] = df['full_content'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

plt.figure(figsize=(15, 6))
for i, (name, df) in enumerate(dataframes.items()):
    plt.subplot(1, 3, i+1)
    sns.histplot(df['polarity'], bins=20, kde=True, color='purple')
    plt.title(f'Sentiment Polarity: {name}')
    plt.axvline(0, color='red', linestyle='--')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Step 6: Summary Statistics for New Features
# Finally, we look at the descriptive statistics for our newly engineered features across all three datasets.

# %%
for name, df in dataframes.items():
    print(f"\n--- Detailed Stats for {name} ---")
    print(df[['extracted_rating', 'word_count', 'polarity']].describe())
# Out:
# --- Detailed Stats for trello_df ---
#        extracted_rating  word_count    polarity
# count        222.000000  222.000000  222.000000
# mean           8.855856   47.869369    0.265456
# std            1.198391    3.462280    0.235425
# min            5.000000   36.000000   -0.291667
# 25%            8.000000   46.000000    0.110278
# 50%            9.000000   48.000000    0.238194
# 75%           10.000000   50.000000    0.386250
# max           10.000000   57.000000    1.000000
#
# --- Detailed Stats for jira_df ---
#        extracted_rating  word_count    polarity
# count        223.000000  223.000000  223.000000
# mean           8.412556   46.089686    0.266674
# std            1.398269    3.831006    0.259187
# min            3.000000   31.000000   -0.500000
# 25%            8.000000   44.000000    0.077500
# 50%            9.000000   46.000000    0.250000
# 75%            9.000000   49.000000    0.400000
# max           10.000000   57.000000    1.000000
#
# --- Detailed Stats for clickup_df ---
#        extracted_rating   word_count     polarity
# count        717.000000  1293.000000  1293.000000
# mean           9.230126    31.634957     0.170511
# std            1.129239    16.937641     0.227910
# min            1.000000    10.000000    -0.800000
# 25%            9.000000    13.000000     0.000000
# 50%           10.000000    41.000000     0.066667
# 75%           10.000000    47.000000     0.300000
# max           10.000000    58.000000     1.000000
