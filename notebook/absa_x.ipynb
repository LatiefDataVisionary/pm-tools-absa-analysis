# %% [markdown]
# <a href="https://colab.research.google.com/github/LatiefDataVisionary/pm-tools-absa-analysis/blob/main/notebook/absa_x.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Import libraries**

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# Set visual configuration
sns.set_theme(style="whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)
plt.rcParams['axes.titlesize'] = 14

# %% [markdown]
# ## **2. Load Data dan Inspect Awal**

# %%
trello_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/x/trello_x_reviews.csv')
jira_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/x/jira_x_reviews.csv')
clickup_df = pd.read_csv('https://raw.githubusercontent.com/LatiefDataVisionary/pm-tools-absa-analysis/refs/heads/main/data/raw/x/clickup_x_reviews.csv')

# %%
trello_df.head(10)
# Out:
#                   timestamp  \
# 0  2026-04-23T18:23:51.000Z
# 1  2026-04-23T11:52:00.000Z
# 2  2026-04-22T18:06:14.000Z
# 3  2026-04-22T18:00:49.000Z
# 4  2026-04-22T06:32:39.000Z
# 5  2026-04-21T13:50:55.000Z
# 6  2026-04-19T14:30:20.000Z
# 7  2026-04-19T13:54:27.000Z
# 8  2026-04-19T04:00:01.000Z
# 9  2026-04-18T20:03:10.000Z
#
#                                                 text target_keyword
# 0  A little over 1 week since officially launched...        @trello
# 1  You could also consider  http:// ProofHub.com ...        @trello
# 2  First open source project collboration of our ...        @trello
# 3  The wait is finally over. Project "Noobieteam"...        @trello
# 4  Strategy isn't a ladder; it's an ecosystem.   ...        @trello
# 5  Most  @trello  users don’t know you can now se...        @trello
# 6  I have over 200 vinyls of all genres that I'm ...        @trello
# 7  ok, now i'm ready to ditch  @OpenAI ,  @canva ...        @trello
# 8  Professionalizing Your Startup: Building a Hig...        @trello
# 9  from  @DPGAlliance  you can find a countless n...        @trello

# %%
jira_df.head(10)
# Out:
#                   timestamp  \
# 0  2026-04-25T08:00:32.000Z
# 1  2026-04-22T11:40:22.000Z
# 2  2026-04-25T11:58:41.000Z
# 3  2026-04-20T14:32:04.000Z
# 4  2026-04-25T12:33:11.000Z
# 5  2026-04-25T12:23:29.000Z
# 6  2026-04-13T18:38:53.000Z
# 7  2026-04-25T09:00:30.000Z
# 8  2026-04-25T12:02:39.000Z
# 9  2026-04-25T12:12:06.000Z
#
#                                                 text          target_keyword
# 0  DEVOPS LAYERS  PLANNING LAYER → Defines projec...  @jira OR jira OR #jira
# 1  Your company's knowledge is trapped.  It's sca...  @jira OR jira OR #jira
# 2  (   ◜ϖ◝ ).;:…(   ◜ϖ◝ ...:.;::..(   ◜;::: .:.;:...  @jira OR jira OR #jira
# 3  New policy from  @Atlassian :   Unless you opt...  @jira OR jira OR #jira
# 4                                                NaN  @jira OR jira OR #jira
# 5       はじめまして、りにゃと申します ぜひ繋がっていただければ嬉しいです！ フォロー失礼します  @jira OR jira OR #jira
# 6                 Yeah, there is, but he forbade it.  @jira OR jira OR #jira
# 7  AREWA24 Taku ce! Tamu ce!! Ta kowa ce!!! Ta Ja...  @jira OR jira OR #jira
# 8              すごいドラマチック勝利 気持ちいいくらい勝ちましたねー おつかれさまでした  @jira OR jira OR #jira
# 9  [ 2026. 04. 25 ] 7.00 PM   Current Followers :...  @jira OR jira OR #jira

# %%
clickup_df.head(10)
# Out:
#                   timestamp  \
# 0  2026-04-17T13:57:24.000Z
# 1  2026-04-23T13:00:37.000Z
# 2  2026-04-10T09:20:00.000Z
# 3  2026-04-15T16:39:13.000Z
# 4  2026-03-26T16:24:25.000Z
# 5  2026-04-22T16:28:18.000Z
# 6  2026-04-17T08:17:27.000Z
# 7  2026-04-18T07:49:32.000Z
# 8  2026-04-05T14:56:38.000Z
# 9  2026-04-17T12:20:34.000Z
#
#                                                 text  \
# 0  I just saw ClickUp launch AI agents that work ...
# 1  AI Tools Ecosystem ┃ ┣  Time Management ┃ ┣  A...
# 2  The biggest problem with clickup is that it al...
# 3  I built a custom agent inside my  @clickup  wo...
# 4  Top AI Productivity Tools You MUST Try in 2026...
# 5      ClickUp is slowly becoming an everything app.
# 6  I got millions of views last week.  And my Cli...
# 7  ClickUp Super Agents are wild.  You can litera...
# 8  Hizi hapa tools 5 za kupanga kazi na ratiba za...
# 9  Plane : un outil de gestion de projet Open Sou...
#
#                     target_keyword
# 0  @clickup OR clickup OR #clickup
# 1  @clickup OR clickup OR #clickup
# 2  @clickup OR clickup OR #clickup
# 3  @clickup OR clickup OR #clickup
# 4  @clickup OR clickup OR #clickup
# 5  @clickup OR clickup OR #clickup
# 6  @clickup OR clickup OR #clickup
# 7  @clickup OR clickup OR #clickup
# 8  @clickup OR clickup OR #clickup
# 9  @clickup OR clickup OR #clickup

# %%
trello_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 285 entries, 0 to 284
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       285 non-null    object
#  1   text            284 non-null    object
#  2   target_keyword  285 non-null    object
# dtypes: object(3)
# memory usage: 6.8+ KB

# %%
jira_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249 entries, 0 to 248
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       249 non-null    object
#  1   text            248 non-null    object
#  2   target_keyword  249 non-null    object
# dtypes: object(3)
# memory usage: 6.0+ KB

# %%
clickup_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 166 entries, 0 to 165
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   timestamp       166 non-null    object
#  1   text            165 non-null    object
#  2   target_keyword  166 non-null    object
# dtypes: object(3)
# memory usage: 4.0+ KB

# %%
dataframes = {
    "trello_df": trello_df,
    "jira_df": jira_df,
    "clickup_df": clickup_df
}

for df_name, df in dataframes.items():
    print(f"--- Null Information for {df_name} ---")
    null_counts = df.isnull().sum()
    null_percentages = (null_counts / len(df)) * 100

    null_info_df = pd.DataFrame({
        'Null Count': null_counts,
        'Null Percentage': null_percentages.round(2)
    })
    print(null_info_df)
    print("\n")
# Out:
# --- Null Information for trello_df ---
#                 Null Count  Null Percentage
# timestamp                0             0.00
# text                     1             0.35
# target_keyword           0             0.00
#
#
# --- Null Information for jira_df ---
#                 Null Count  Null Percentage
# timestamp                0              0.0
# text                     1              0.4
# target_keyword           0              0.0
#
#
# --- Null Information for clickup_df ---
#                 Null Count  Null Percentage
# timestamp                0              0.0
# text                     1              0.6
# target_keyword           0              0.0

# %%
for df_name, df in dataframes.items():
    print(f"--- Duplicates Information for {df_name} ---")
    duplicate_counts = df.duplicated().sum()
    print(duplicate_counts)
    print("\n")
# Out:
# --- Duplicates Information for trello_df ---
# 0
#
#
# --- Duplicates Information for jira_df ---
# 0
#
#
# --- Duplicates Information for clickup_df ---
# 0

# %% [markdown]
# ## **3. EDA Awal**
# In this section, we will perform a deep dive into the review data for Trello, Jira, and ClickUp.

# %% [markdown]
# ### **3.1 Analisis Distribusi Teks (Panjang Karakter & Jumlah Kata)**

# %%
def analyze_text_distribution(df, label):
    """
    Calculates and visualizes the distribution of text lengths and word counts.

    Args:
        df (pd.DataFrame): The input dataframe containing a 'text' column.
        label (str): The name of the platform for labeling plots.
    """
    # Remove potential nulls for analysis stability
    temp_df = df.dropna(subset=['text']).copy()

    # Feature engineering for EDA
    temp_df['char_length'] = temp_df['text'].apply(len)
    temp_df['word_count'] = temp_df['text'].apply(lambda x: len(str(x).split()))

    fig, axes = plt.subplots(1, 2, figsize=(16, 5))

    # Character length distribution
    sns.histplot(temp_df['char_length'], kde=True, ax=axes[0], color='skyblue')
    axes[0].set_title(f'Distribusi Panjang Karakter - {label}')
    axes[0].set_xlabel('Jumlah Karakter')
    axes[0].set_ylabel('Frekuensi')

    # Word count distribution
    sns.histplot(temp_df['word_count'], kde=True, ax=axes[1], color='salmon')
    axes[1].set_title(f'Distribusi Jumlah Kata - {label}')
    axes[1].set_xlabel('Jumlah Kata')
    axes[1].set_ylabel('Frekuensi')

    plt.tight_layout()
    plt.show()

    # Descriptive statistics
    print(f"--- Statistik Deskriptif Teks: {label} ---")
    display(temp_df[['char_length', 'word_count']].describe().transpose())

# Execute analysis for each platform
for name, data in [("Trello", trello_df), ("Jira", jira_df), ("ClickUp", clickup_df)]:
    analyze_text_distribution(data, name)
# Out:
# --- Statistik Deskriptif Teks: Trello ---
#              count        mean        std  min    25%    50%    75%    max
# char_length  284.0  146.112676  88.546257  3.0  64.75  136.0  223.5  404.0
# word_count   284.0   22.028169  16.040560  1.0   7.00   20.0   35.0   56.0
# --- Statistik Deskriptif Teks: Jira ---
#              count        mean        std  min   25%   50%     75%    max
# char_length  248.0  118.020161  99.686084  2.0  41.0  75.0  199.25  425.0
# word_count   248.0   17.443548  16.792278  1.0   3.0  10.0   31.00   57.0
# --- Statistik Deskriptif Teks: ClickUp ---
#              count        mean        std  min   25%    50%    75%    max
# char_length  165.0  167.496970  93.057131  6.0  76.0  166.0  264.0  402.0
# word_count   165.0   27.793939  16.002476  1.0  13.0   29.0   41.0   72.0

# %% [markdown]
# ### **3.2 Analisis Tren Temporal Ulasan**

# %%
def analyze_temporal_trends(df, label):
    """
    Analyzes the frequency of reviews over time.

    Args:
        df (pd.DataFrame): The input dataframe containing a 'timestamp' column.
        label (str): The name of the platform.
    """
    df_temp = df.copy()
    # Convert to datetime and handle timezone awareness
    df_temp['timestamp'] = pd.to_datetime(df_temp['timestamp'])
    df_temp['date'] = df_temp['timestamp'].dt.date

    # Aggregate by date
    daily_counts = df_temp.groupby('date').size().reset_index(name='count')

    plt.figure(figsize=(14, 5))
    plt.plot(daily_counts['date'], daily_counts['count'], marker='o', linestyle='-', color='teal')
    plt.title(f'Tren Frekuensi Ulasan Harian - {label}')
    plt.xlabel('Tanggal')
    plt.ylabel('Jumlah Ulasan')
    plt.xticks(rotation=45)
    plt.grid(True, alpha=0.3)
    plt.show()

analyze_temporal_trends(trello_df, "Trello")
analyze_temporal_trends(jira_df, "Jira")
analyze_temporal_trends(clickup_df, "ClickUp")

# %% [markdown]
# ### **3.3 Perbandingan Volume Data Antar Platform**

# %%
def compare_platform_volume(dfs_dict):
    """
    Visualizes the comparative volume of data across all project management tools.

    Args:
        dfs_dict (dict): Dictionary of platform names and their respective dataframes.
    """
    labels = list(dfs_dict.keys())
    counts = [len(df) for df in dfs_dict.values()]

    plt.figure(figsize=(10, 6))
    colors = ['#0079BF', '#0052CC', '#7B68EE'] # Brand-aligned colors for Trello, Jira, ClickUp

    bars = plt.bar(labels, counts, color=colors)
    plt.title('Perbandingan Volume Data Ulasan Antar Platform')
    plt.ylabel('Total Ulasan')

    # Annotate bars with exact values
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval + 2, yval, ha='center', va='bottom', fontweight='bold')

    plt.show()

platform_comparison = {
    'Trello': trello_df,
    'Jira': jira_df,
    'ClickUp': clickup_df
}
compare_platform_volume(platform_comparison)

# %% [markdown]
# ### **3.4 Analisis N-Gram (Frasa Kontekstual)**

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd

def analyze_top_ngrams(df, platform_name, n=2, top_k=10):
    """
    Performs n-gram analysis to identify common phrases and contextual patterns.

    Args:
        df (pd.DataFrame): Dataframe with 'text' column.
        platform_name (str): Name of the platform.
        n (int): The n in n-gram (default 2 for bigrams).
        top_k (int): Number of top phrases to display.
    """
    # Pre-cleaning for EDA visualization only (removing common URLs and mentions)
    clean_text = df['text'].dropna().str.replace(r'http\S+|@\S+', '', regex=True)

    vec = CountVectorizer(ngram_range=(n, n), stop_words='english').fit(clean_text)
    bag_of_words = vec.transform(clean_text)
    sum_words = bag_of_words.sum(axis=0)

    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq = sorted(words_freq, key=lambda x: x[1], reverse=True)[:top_k]

    ngram_df = pd.DataFrame(words_freq, columns=['phrase', 'frequency'])

    plt.figure(figsize=(10, 6))
    sns.barplot(x='frequency', y='phrase', data=ngram_df, palette='viridis')
    plt.title(f'Top {n}-Grams: {platform_name}')
    plt.xlabel('Frekuensi')
    plt.ylabel('Frasa')
    plt.show()

# Execute contextual phrase analysis
for name, data in [("Trello", trello_df), ("Jira", jira_df), ("ClickUp", clickup_df)]:
    analyze_top_ngrams(data, name)
# Out:
# /tmp/ipykernel_12554/2220371225.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='frequency', y='phrase', data=ngram_df, palette='viridis')
# /tmp/ipykernel_12554/2220371225.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='frequency', y='phrase', data=ngram_df, palette='viridis')
# /tmp/ipykernel_12554/2220371225.py:27: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='frequency', y='phrase', data=ngram_df, palette='viridis')

# %% [markdown]
# ### **3.5 Identifikasi Isu Kualitas Data (Ulasan Sangat Pendek)**

# %%
def identify_data_quality_issues(df, label):
    """
    Identifies potential noise in the dataset such as extremely short reviews.

    Args:
        df (pd.DataFrame): Input dataframe.
        label (str): Platform name.
    """
    temp_df = df.dropna(subset=['text']).copy()
    temp_df['word_count'] = temp_df['text'].apply(lambda x: len(str(x).split()))

    # Threshold: reviews with less than 3 words are often just 'nice', 'good', or noise
    short_reviews = temp_df[temp_df['word_count'] < 3]

    print(f"--- Kualitas Data: {label} ---")
    print(f"Total ulasan yang sangat pendek (< 3 kata): {len(short_reviews)}")
    if len(short_reviews) > 0:
        print("Contoh ulasan pendek:")
        display(short_reviews['text'].head(3))
    print("-" * 30)

for name, data in [("Trello", trello_df), ("Jira", jira_df), ("ClickUp", clickup_df)]:
    identify_data_quality_issues(data, name)
# Out:
# --- Kualitas Data: Trello ---
# Total ulasan yang sangat pendek (< 3 kata): 26
# Contoh ulasan pendek:
# 11       @trello
# 16      Adelante
# 44    bookmarked
# Name: text, dtype: object
# ------------------------------
# --- Kualitas Data: Jira ---
# Total ulasan yang sangat pendek (< 3 kata): 53
# Contoh ulasan pendek:
# 11    初めまして、お声掛けありがとうございます！ 引き換え後の送金でも宜しければ交換可能なので、お...
# 16                                         jira tickets
# 29    遅くなりました！お呼び出しありがとうございます！！ シルバ「ありがとな〜！呼んでくれて！バー...
# Name: text, dtype: object
# ------------------------------
# --- Kualitas Data: ClickUp ---
# Total ulasan yang sangat pendek (< 3 kata): 5
# Contoh ulasan pendek:
# 76            0xe242bbcae0d7f18bfcb772240aa5cedfa6e0f2ba
# 97     最近ClaudeCodeくんが「これはClickOpsで作られたXXです」って言うようになっ...
# 115    DEgQzvMv9SvebHtBaSKnb6iRSHJHaVLA3phZyzGjbrrr  ...
# Name: text, dtype: object
# ------------------------------

# %% [markdown]
# ### **3.6 Audit Linguistik & Deteksi Bahasa**

# %%
# !pip install langdetect -q
from langdetect import detect, DetectorFactory
from collections import Counter
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Ensure reproducible results
DetectorFactory.seed = 42

def detect_language_distribution(df, title_label=""):
    """
    Detects languages in the 'text' column and provides a professional statistical summary.
    """
    def safe_detect(text):
        try:
            if pd.isna(text) or text.strip() == "":
                return 'unknown'
            return detect(text)
        except:
            return 'unknown'

    print(f"--- Menjalankan Deteksi Bahasa: {title_label} ---")
    df = df.copy()
    df['detected_lang'] = df['text'].apply(safe_detect)

    # Statistical aggregation
    lang_counts = df['detected_lang'].value_counts()
    lang_pcts = (df['detected_lang'].value_counts(normalize=True) * 100).round(3)

    lang_report = pd.DataFrame({
        'Quantity': lang_counts,
        'Percentage (%)': lang_pcts
    })

    # Visualization
    plt.figure(figsize=(12, 6))
    sns.barplot(x=lang_report.index, y='Quantity', data=lang_report, palette='magma')
    plt.title(f'Distribusi Bahasa - {title_label}')
    plt.xlabel('Language Code (ISO)')
    plt.ylabel('Jumlah Ulasan')

    for i, v in enumerate(lang_report['Quantity']):
        plt.text(i, v + 0.5, str(v), ha='center', fontweight='bold')

    plt.show()

    print("Table Distribusi Bahasa:")
    display(lang_report)
    return df

# Menggabungkan dataset mentah (raw) tanpa filter pembersihan
raw_combined = pd.concat([
    trello_df.assign(platform='trello'),
    jira_df.assign(platform='jira'),
    clickup_df.assign(platform='clickup')
], ignore_index=True)

# Menjalankan deteksi pada data mentah
raw_combined_with_lang = detect_language_distribution(raw_combined, "Raw Data (EDA Stage)")
# Out:
# --- Menjalankan Deteksi Bahasa: Raw Data (EDA Stage) ---
# /tmp/ipykernel_12554/2400862126.py:38: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lang_report.index, y='Quantity', data=lang_report, palette='magma')
# Table Distribusi Bahasa:
#                Quantity  Percentage (%)
# detected_lang
# en                  465          66.429
# ja                   99          14.143
# ar                   27           3.857
# th                   22           3.143
# id                   15           2.143
# es                   13           1.857
# sw                   10           1.429
# unknown               7           1.000
# so                    7           1.000
# fr                    5           0.714
# it                    4           0.571
# da                    3           0.429
# cy                    3           0.429
# ca                    3           0.429
# pt                    3           0.429
# nl                    2           0.286
# sv                    2           0.286
# vi                    1           0.143
# fi                    1           0.143
# ko                    1           0.143
# ro                    1           0.143
# tr                    1           0.143
# hu                    1           0.143
# et                    1           0.143
# no                    1           0.143
# lt                    1           0.143
# sl                    1           0.143

# %%
# !pip install deep-translator -q
from deep_translator import GoogleTranslator
import time

def translate_to_english(df, text_col='text', lang_col='detected_lang'):
    """
    Translates non-English text to English using Google Translator.
    """
    translator = GoogleTranslator(source='auto', target='en')
    df_translated = df.copy()

    # Select rows where language is not 'en' and not 'unknown'
    to_translate_mask = (df_translated[lang_col] != 'en') & (df_translated[lang_col] != 'unknown')

    print(f"--- Starting translation for {to_translate_mask.sum()} entries ---")

    def safe_translate(text):
        if pd.isna(text) or text.strip() == "":
            return text
        try:
            # Adding a small delay to avoid rate limiting for large batches
            return translator.translate(text)
        except Exception as e:
            return text

    # Apply translation only where needed to save time
    df_translated.loc[to_translate_mask, 'text_translated'] = df_translated.loc[to_translate_mask, text_col].apply(safe_translate)

    # For English/Unknown, keep the original text
    df_translated['text_translated'] = df_translated['text_translated'].fillna(df_translated[text_col])

    print("--- Translation Complete ---")
    return df_translated

# Run translation on the raw dataset from the language audit results
raw_translated_df = translate_to_english(raw_combined_with_lang)

# Display sample of translated results
display(raw_translated_df[raw_translated_df['detected_lang'] != 'en'][['text', 'text_translated', 'detected_lang']].head(10))
# Out:
# --- Starting translation for 228 entries ---
# --- Translation Complete ---
#                                                  text  \
# 11                                            @trello
# 15  ¡Claro, Silvina!  Aquí va tu plantilla lista p...
# 16                                           Adelante
# 20  4 y 5   @trello   sincronizado con  @googlecal...
# 24                       استراتيجية محضة وأفكار رائعة
# 44                                         bookmarked
# 47  トリさん大好き　ﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘﾄﾘ...
# 48  عروض ترينديول Trendyol مع ترندول بتتحول لفرصة ...
# 49  こんばんは。お世話になっております。 お返事とご快諾ありがとうございます。フォローは問題あり...
# 50  こんばんは、お返事頂きありがとうございます。 取引可能との事嬉しく思います。 お取引のためフ...
#
#                                       text_translated detected_lang
# 11                                            @trello            it
# 15  Of course, Silvina!  Here is your template rea...            es
# 16                                            Forward            es
# 20  4 and 5 @trello synchronized with @googlecalen...            es
# 24                      Pure strategy and great ideas            ar
# 44                                         bookmarked            so
# 47  I love Tori-san, I love you so much. Tritritri...            ja
# 48  Trendyol offers with Trendyol turn into a gold...            ar
# 49  Good evening. Thank you for your help. Thank y...            ja
# 50  Good evening, thank you for your reply. I'm gl...            ja

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from langdetect import detect, DetectorFactory

# Ensure reproducible results, assuming DetectorFactory.seed is already set from previous cells
DetectorFactory.seed = 42

def validate_translated_languages(df_translated_data, text_col='text_translated'):
    """
    Validates the language distribution after translation by re-detecting languages
    in the specified text column and displaying the distribution.
    """
    temp_df = df_translated_data.copy()

    def safe_detect_new(text):
        try:
            if pd.isna(text) or text.strip() == "":
                return 'unknown'
            return detect(text)
        except:
            return 'unknown'

    print(f"--- Validasi Bahasa Setelah Terjemahan ({text_col}) ---")
    temp_df['detected_lang_validated'] = temp_df[text_col].apply(safe_detect_new)

    lang_counts_validated = temp_df['detected_lang_validated'].value_counts()
    lang_pcts_validated = (temp_df['detected_lang_validated'].value_counts(normalize=True) * 100).round(3)

    lang_report_validated = pd.DataFrame({
        'Quantity': lang_counts_validated,
        'Percentage (%)': lang_pcts_validated
    })

    # Visualization
    plt.figure(figsize=(12, 6))
    sns.barplot(x=lang_report_validated.index, y='Quantity', data=lang_report_validated, palette='viridis')
    plt.title(f'Distribusi Bahasa Setelah Terjemahan - Kolom: {text_col}')
    plt.xlabel('Language Code (ISO)')
    plt.ylabel('Jumlah Ulasan')

    # Annotate bars with exact values
    for i, v in enumerate(lang_report_validated['Quantity']):
        plt.text(i, v + 0.5, str(v), ha='center', fontweight='bold')

    plt.show()

    print("Table Distribusi Bahasa Setelah Terjemahan:")
    display(lang_report_validated)
    return temp_df

# Run validation on the raw_translated_df
raw_translated_df_validated = validate_translated_languages(raw_translated_df, text_col='text_translated')
# Out:
# --- Validasi Bahasa Setelah Terjemahan (text_translated) ---
# /tmp/ipykernel_12554/1881183157.py:37: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lang_report_validated.index, y='Quantity', data=lang_report_validated, palette='viridis')
# Table Distribusi Bahasa Setelah Terjemahan:
#                          Quantity  Percentage (%)
# detected_lang_validated
# en                            643          91.857
# unknown                         9           1.286
# so                              5           0.714
# ca                              4           0.571
# da                              4           0.571
# fr                              3           0.429
# cy                              3           0.429
# sw                              3           0.429
# it                              3           0.429
# nl                              2           0.286
# ja                              2           0.286
# de                              2           0.286
# ro                              2           0.286
# es                              2           0.286
# sv                              2           0.286
# sl                              2           0.286
# sq                              1           0.143
# vi                              1           0.143
# fi                              1           0.143
# hu                              1           0.143
# mk                              1           0.143
# et                              1           0.143
# no                              1           0.143
# lt                              1           0.143
# sk                              1           0.143

# %% [markdown]
# ## **4. Preprocessing Data untuk Analisis Sentimen**
# Bagian ini mencakup pembersihan data, integrasi dataset, dan transformasi fitur teks sebelum masuk ke tahap analisis sentiment ABSA.

# %% [markdown]
# ### **4.1 Pembersihan dan Normalisasi Teks**
#
# Langkah pertama dalam preprocessing adalah membersihkan dan menormalisasi teks ulasan. Fungsi `professional_cleaner` yang telah kita definisikan melakukan serangkaian tugas penting untuk mempersiapkan teks agar siap untuk analisis sentimen berbasis aspek (ABSA):
#
# *   **Lowercase dan Penghapusan Entitas Tidak Relevan**: Mengubah semua teks menjadi huruf kecil dan menghilangkan URL, mention Twitter (`@username`), serta hashtag (`#topic`) yang umumnya tidak membawa nilai sentimen intrinsik.
# *   **Penanganan Karakter Non-ASCII**: Memastikan hanya karakter ASCII (biasanya Inggris) yang dipertahankan, menghilangkan karakter dari bahasa atau simbol lain yang mungkin mengganggu analisis.
# *   **Penghapusan Angka dan Puntuasi**: Menghilangkan angka dan tanda baca yang tidak esensial, fokus pada kata-kata yang membentuk sentimen dan aspek.
# *   **Tokenisasi, Lemmatisasi, dan Penghapusan Stopword**: Memecah teks menjadi kata-kata (token), menormalisasi kata-kata ke bentuk dasarnya (misalnya, 'running' menjadi 'run', 'features' menjadi 'feature') agar aspek yang sama tidak terpecah, serta menghilangkan kata-kata umum (stopwords) yang tidak memiliki makna sentimen kuat (misalnya, 'the', 'is', 'a').

# %%
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK resources
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)

lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

def professional_cleaner(text):
    """
    Super-Professional Text Preprocessing for ABSA.
    Focuses on preserving semantic meaning while removing syntactic noise.
    """
    if not isinstance(text, str): return ""

    # 1. Lowercase & URL/Handle/Hashtag Removal
    text = text.lower()
    text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
    text = re.sub(r'@\w+|#\w+', '', text)

    # 2. Handle Non-ASCII (Keep only English chars for this specific analysis)
    text = re.sub(r'[^\x00-\x7F]+', ' ', text)

    # 3. Specific Noise: Numbers & Punctuation (Except potentially useful symbols for ABSA if needed)
    text = re.sub(r'[^a-z\s]', ' ', text)

    # 4. Tokenization & Lemmatization & Stopword Removal
    tokens = text.split()
    # We lemmatize to group similar words for aspect extraction (e.g., 'features' -> 'feature')
    cleaned_tokens = [lemmatizer.lemmatize(w) for w in tokens if w not in stop_words and len(w) > 2]

    return " ".join(cleaned_tokens)

def unify_and_clean_datasets(dfs_dict):
    """
    Enterprise-grade data integration and quality filtering.
    """
    processed_dfs = []

    for name, df in dfs_dict.items():
        temp_df = df.copy()
        temp_df['platform'] = name.lower()

        # Initial cleanup
        temp_df.dropna(subset=['text'], inplace=True)

        # Apply advanced scrubbing
        temp_df['clean_text'] = temp_df['text'].apply(professional_cleaner)

        # Filtering: ABSA requires enough context.
        # Increased threshold to 3 words *after* cleaning to ensure quality aspects exist.
        temp_df = temp_df[temp_df['clean_text'].apply(lambda x: len(x.split()) >= 3)]

        # Standardize metadata
        temp_df['timestamp'] = pd.to_datetime(temp_df['timestamp'])
        temp_df['product'] = name.lower()

        processed_dfs.append(temp_df)

    # Final Integration
    master_df = pd.concat(processed_dfs, ignore_index=True)
    if 'target_keyword' in master_df.columns:
        master_df.drop(columns=['target_keyword'], inplace=True)

    return master_df

# %% [markdown]
# ### **4.2 Integrasi Data dan Pembuatan Master DataFrame**
#
# Setelah teks dibersihkan dan dinormalisasi secara individu untuk setiap platform, langkah selanjutnya adalah mengintegrasikan semua DataFrame menjadi satu `master_df` (yang kita sebut `combined_df`). Fungsi `unify_and_clean_datasets` tidak hanya menggabungkan data, tetapi juga menerapkan filter kualitas:
#
# *   **Penandaan Platform**: Menambahkan kolom `platform` ke setiap ulasan untuk melacak asal ulasan (Trello, Jira, ClickUp).
# *   **Penanganan Nilai Kosong**: Menghapus baris yang memiliki nilai kosong di kolom `text`, karena ulasan tanpa teks tidak dapat dianalisis.
# *   **Filter Kualitas Teks**: Memastikan hanya ulasan yang memiliki minimal 3 kata setelah proses pembersihan yang dipertahankan. Ini penting untuk ABSA karena ulasan yang terlalu pendek seringkali tidak memberikan konteks yang cukup untuk mengekstrak aspek dan sentimen yang berarti.
# *   **Standardisasi Kolom Waktu**: Mengonversi kolom `timestamp` ke format datetime standar untuk konsistensi.
# *   **Integrasi Akhir**: Menggabungkan semua DataFrame yang telah diproses menjadi satu `combined_df` yang siap untuk analisis lebih lanjut.

# %%
# Execute high-fidelity data integration
platform_map = {'Trello': trello_df, 'Jira': jira_df, 'ClickUp': clickup_df}
combined_df = unify_and_clean_datasets(platform_map)

print("--- Audit Master Dataframe (ABSA Ready) ---")
print(f"Distribusi Platform:\n{combined_df['platform'].value_counts()}")
print("-" * 50)
display(combined_df.head())
combined_df.info(10)
# Out:
# --- Audit Master Dataframe (ABSA Ready) ---
# Distribusi Platform:
# platform
# trello     222
# clickup    159
# jira       140
# Name: count, dtype: int64
# --------------------------------------------------
#                   timestamp  \
# 0 2026-04-23 18:23:51+00:00
# 1 2026-04-23 11:52:00+00:00
# 2 2026-04-22 18:06:14+00:00
# 3 2026-04-22 18:00:49+00:00
# 4 2026-04-22 06:32:39+00:00
#
#                                                 text platform  \
# 0  A little over 1 week since officially launched...   trello
# 1  You could also consider  http:// ProofHub.com ...   trello
# 2  First open source project collboration of our ...   trello
# 3  The wait is finally over. Project "Noobieteam"...   trello
# 4  Strategy isn't a ladder; it's an ecosystem.   ...   trello
#
#                                           clean_text product
# 0  little week since officially launched power mo...  trello
# 1  could also consider proofhub com solid option ...  trello
# 2  first open source project collboration inferen...  trello
# 3  wait finally project noobieteam github com gra...  trello
# 4  strategy ladder ecosystem okrs fail due goal a...  trello
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 521 entries, 0 to 520
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timestamp   521 non-null    datetime64[ns, UTC]
#  1   text        521 non-null    object
#  2   platform    521 non-null    object
#  3   clean_text  521 non-null    object
#  4   product     521 non-null    object
# dtypes: datetime64[ns, UTC](1), object(4)
# memory usage: 20.5+ KB

# %% [markdown]
# ### **4.3 Verifikasi Struktur Data Gabungan**
#
# Setelah penggabungan dan pembersihan, kita perlu memastikan bahwa struktur data `combined_df` sudah siap untuk analisis sentimen ABSA. Kolom `platform` sangat penting untuk melakukan segmentasi analisis per alat Project Management (PM).

# %%
# Contoh memfilter data untuk satu platform (misal: Trello)
trello_clean_df = combined_df[combined_df['platform'] == 'trello']

print(f"Jumlah ulasan Trello setelah pembersihan: {len(trello_clean_df)}")
display(trello_clean_df.head())

# Contoh memfilter data untuk Jira
jira_clean_df = combined_df[combined_df['platform'] == 'jira']

print(f"\nJumlah ulasan Jira setelah pembersihan: {len(jira_clean_df)}")
display(jira_clean_df.head())

# Contoh memfilter data untuk ClickUp
clickup_clean_df = combined_df[combined_df['platform'] == 'clickup']

print(f"\nJumlah ulasan ClickUp setelah pembersihan: {len(clickup_clean_df)}")
display(clickup_clean_df.head())
# Out:
# Jumlah ulasan Trello setelah pembersihan: 222
#                   timestamp  \
# 0 2026-04-23 18:23:51+00:00
# 1 2026-04-23 11:52:00+00:00
# 2 2026-04-22 18:06:14+00:00
# 3 2026-04-22 18:00:49+00:00
# 4 2026-04-22 06:32:39+00:00
#
#                                                 text platform  \
# 0  A little over 1 week since officially launched...   trello
# 1  You could also consider  http:// ProofHub.com ...   trello
# 2  First open source project collboration of our ...   trello
# 3  The wait is finally over. Project "Noobieteam"...   trello
# 4  Strategy isn't a ladder; it's an ecosystem.   ...   trello
#
#                                           clean_text product
# 0  little week since officially launched power mo...  trello
# 1  could also consider proofhub com solid option ...  trello
# 2  first open source project collboration inferen...  trello
# 3  wait finally project noobieteam github com gra...  trello
# 4  strategy ladder ecosystem okrs fail due goal a...  trello
# Jumlah ulasan Jira setelah pembersihan: 140
#                     timestamp  \
# 222 2026-04-25 08:00:32+00:00
# 223 2026-04-22 11:40:22+00:00
# 224 2026-04-20 14:32:04+00:00
# 225 2026-04-25 09:00:30+00:00
# 226 2026-04-25 12:12:06+00:00
#
#                                                   text platform  \
# 222  DEVOPS LAYERS  PLANNING LAYER → Defines projec...     jira
# 223  Your company's knowledge is trapped.  It's sca...     jira
# 224  New policy from  @Atlassian :   Unless you opt...     jira
# 225  AREWA24 Taku ce! Tamu ce!! Ta kowa ce!!! Ta Ja...     jira
# 226  [ 2026. 04. 25 ] 7.00 PM   Current Followers :...     jira
#
#                                             clean_text product
# 222  devops layer planning layer defines project go...    jira
# 223  company knowledge trapped scattered across sla...    jira
# 224  new policy unless opt august data jira conflue...    jira
# 225  arewa taku tamu kowa jama naku salon sai kuyi ...    jira
# 226                      current follower ppwpp family    jira
# Jumlah ulasan ClickUp setelah pembersihan: 159
#                     timestamp  \
# 362 2026-04-17 13:57:24+00:00
# 363 2026-04-23 13:00:37+00:00
# 364 2026-04-10 09:20:00+00:00
# 365 2026-04-15 16:39:13+00:00
# 366 2026-03-26 16:24:25+00:00
#
#                                                   text platform  \
# 362  I just saw ClickUp launch AI agents that work ...  clickup
# 363  AI Tools Ecosystem ┃ ┣  Time Management ┃ ┣  A...  clickup
# 364  The biggest problem with clickup is that it al...  clickup
# 365  I built a custom agent inside my  @clickup  wo...  clickup
# 366  Top AI Productivity Tools You MUST Try in 2026...  clickup
#
#                                             clean_text  product
# 362  saw clickup launch agent work without burning ...  clickup
# 363  tool ecosystem time management scheduling befo...  clickup
# 364  biggest problem clickup allows bullshit accumu...  clickup
# 365  built custom agent inside workspace tag agent ...  clickup
# 366  top productivity tool must try want work faste...  clickup

# %% [markdown]
# ## **5. Aspect-Based Sentiment Analysis (ABSA)**
#
# Bagian ini mengimplementasikan analisis sentimen berbasis aspek untuk mengidentifikasi fitur spesifik dari produk (seperti UI, fitur, atau harga) dan sentimen yang terkait dengannya. Kita akan menggunakan *dependency parsing* untuk mengekstrak hubungan antara *noun* (aspek) dan *adjective* (sentimen).

# %%
import spacy
import pandas as pd
import numpy as np
from textblob import TextBlob
from collections import defaultdict

# Memuat model bahasa Inggris Spacy dengan efisiensi tinggi
try:
    nlp = spacy.load('en_core_web_sm')
except OSError:
    import os
    os.system('python -m spacy download en_core_web_sm')
    nlp = spacy.load('en_core_web_sm')

def categorize_sentiment(score):
    """
    Mengklasifikasikan skor polaritas numerik secara biner (Positive/Negative).
    Menghilangkan kategori Neutral sesuai instruksi khusus.
    """
    # Menggunakan threshold 0 sebagai pembatas biner murni
    if score >= 0:
        return 'Positive'
    else:
        return 'Negative'

def extract_refined_absa(text_series):
    """
    Pipeline ekstraksi aspek tingkat lanjut dengan penanganan negasi dan klasifikasi biner.
    """
    results = []

    for doc in nlp.pipe(text_series, batch_size=50):
        for token in doc:
            if token.pos_ in ['NOUN', 'PROPN']:
                aspect = token.text
                current_aspect_sentiments = []

                for child in token.children:
                    if child.pos_ == 'ADJ':
                        polarity = TextBlob(child.text).sentiment.polarity

                        is_negated = any(gchild.dep_ == 'neg' for gchild in child.children)
                        if is_negated:
                            polarity *= -1

                        current_aspect_sentiments.append(polarity)

                if current_aspect_sentiments:
                    avg_score = np.mean(current_aspect_sentiments)
                    results.append({
                        'aspect': aspect.lower(),
                        'polarity_score': avg_score,
                        'sentiment_label': categorize_sentiment(avg_score)
                    })

    return pd.DataFrame(results)

def analyze_platform_intelligence(df, platform_name):
    """
    Menghasilkan laporan intelijen ABSA biner untuk platform tertentu.
    """
    platform_data = df[df['platform'] == platform_name.lower()]
    absa_raw = extract_refined_absa(platform_data['clean_text'])

    if absa_raw.empty:
        return None

    absa_report = absa_raw.groupby('aspect').agg({
        'polarity_score': ['mean', 'std'],
        'aspect': 'count'
    })

    absa_report.columns = ['avg_sentiment', 'sentiment_volatility', 'mention_frequency']
    absa_report['final_label'] = absa_report['avg_sentiment'].apply(categorize_sentiment)

    significant_report = absa_report[absa_report['mention_frequency'] > 2].sort_values(by='mention_frequency', ascending=False)

    return significant_report

# %%
from IPython.display import display, HTML

def style_strategic_report(df, platform_name):
    """
    Menerapkan styling profesional berbasis HTML/CSS untuk laporan ABSA.
    """
    brand_colors = {
        'TRELLO': '#0079BF',
        'JIRA': '#0052CC',
        'CLICKUP': '#7B68EE'
    }
    color = brand_colors.get(platform_name.upper(), '#333')

    header_html = f"""
    <div style='border-left: 10px solid {color}; padding: 15px; background-color: #f8f9fa; margin: 20px 0;'>
        <h2 style='color: {color}; margin: 0; font-family: sans-serif;'>STRATEGIC INTELLIGENCE: {platform_name.upper()}</h2>
        <p style='margin: 5px 0 0 0; color: #666; font-style: italic;'>Binary Sentiment Aspect Distribution Analysis</p>
    </div>
    """

    def color_sentiment(val):
        color_text = '#28a745' if val == 'Positive' else '#dc3545'
        return f'color: {color_text}; font-weight: bold;'

    def highlight_score(val):
        weight = 'bold' if abs(val) > 0.3 else 'normal'
        return f'font-weight: {weight};'

    # Update: Using .map instead of .applymap to avoid FutureWarnings
    styled_df = df.style\
        .map(color_sentiment, subset=['final_label'])\
        .map(highlight_score, subset=['avg_sentiment'])\
        .format({'avg_sentiment': '{:.3f}', 'sentiment_volatility': '{:.3f}'})\
        .set_table_styles([
            {'selector': 'th', 'props': [('background-color', color), ('color', 'white'), ('font-family', 'sans-serif')]},
            {'selector': 'td', 'props': [('font-family', 'monospace')]}
        ])

    display(HTML(header_html))
    display(styled_df)
    display(HTML("<div style='margin-bottom: 40px; border-bottom: 2px solid #eee;'></div>"))

platforms = ['trello', 'jira', 'clickup']
strategic_insights = {}

print("System: Initiating Professional Visual Rendering Pipeline...\n")

for p in platforms:
    report = analyze_platform_intelligence(combined_df, p)

    if report is not None:
        strategic_insights[p] = report
        style_strategic_report(report.head(12), p)
    else:
        display(HTML(f"<p style='color: orange;'><b>Warning:</b> Insufficient data for platform {p.upper()}</p>"))
# Out:
# System: Initiating Professional Visual Rendering Pipeline...
#     <div style='border-left: 10px solid #0079BF; padding: 15px; background-color: #f8f9fa; margin: 20px 0;'>
#         <h2 style='color: #0079BF; margin: 0; font-family: sans-serif;'>STRATEGIC INTELLIGENCE: TRELLO</h2>
#         <p style='margin: 5px 0 0 0; color: #666; font-style: italic;'>Binary Sentiment Aspect Distribution Analysis</p>
#     </div>
# <style type="text/css">
# #T_660fd th {
#   background-color: #0079BF;
#   color: white;
#   font-family: sans-serif;
# }
# #T_660fd td {
#   font-family: monospace;
# }
# #T_660fd_row0_col0, #T_660fd_row1_col0, #T_660fd_row2_col0, #T_660fd_row3_col0, #T_660fd_row4_col0, #T_660fd_row5_col0, #T_660fd_row6_col0, #T_660fd_row7_col0, #T_660fd_row8_col0, #T_660fd_row9_col0, #T_660fd_row10_col0, #T_660fd_row11_col0 {
#   font-weight: normal;
# }
# #T_660fd_row0_col3, #T_660fd_row1_col3, #T_660fd_row3_col3, #T_660fd_row4_col3, #T_660fd_row5_col3, #T_660fd_row6_col3, #T_660fd_row7_col3, #T_660fd_row8_col3, #T_660fd_row9_col3, #T_660fd_row10_col3, #T_660fd_row11_col3 {
#   color: #28a745;
#   font-weight: bold;
# }
# #T_660fd_row2_col3 {
#   color: #dc3545;
#   font-weight: bold;
# }
# </style>
# <table id="T_660fd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_660fd_level0_col0" class="col_heading level0 col0" >avg_sentiment</th>
#       <th id="T_660fd_level0_col1" class="col_heading level0 col1" >sentiment_volatility</th>
#       <th id="T_660fd_level0_col2" class="col_heading level0 col2" >mention_frequency</th>
#       <th id="T_660fd_level0_col3" class="col_heading level0 col3" >final_label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_660fd_level0_row0" class="row_heading level0 row0" >trello</th>
#       <td id="T_660fd_row0_col0" class="data row0 col0" >0.095</td>
#       <td id="T_660fd_row0_col1" class="data row0 col1" >0.157</td>
#       <td id="T_660fd_row0_col2" class="data row0 col2" >10</td>
#       <td id="T_660fd_row0_col3" class="data row0 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row1" class="row_heading level0 row1" >board</th>
#       <td id="T_660fd_row1_col0" class="data row1 col0" >0.019</td>
#       <td id="T_660fd_row1_col1" class="data row1 col1" >0.052</td>
#       <td id="T_660fd_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_660fd_row1_col3" class="data row1 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row2" class="row_heading level0 row2" >team</th>
#       <td id="T_660fd_row2_col0" class="data row2 col0" >-0.039</td>
#       <td id="T_660fd_row2_col1" class="data row2 col1" >0.205</td>
#       <td id="T_660fd_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_660fd_row2_col3" class="data row2 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row3" class="row_heading level0 row3" >progress</th>
#       <td id="T_660fd_row3_col0" class="data row3 col0" >0.136</td>
#       <td id="T_660fd_row3_col1" class="data row3 col1" >0.214</td>
#       <td id="T_660fd_row3_col2" class="data row3 col2" >7</td>
#       <td id="T_660fd_row3_col3" class="data row3 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row4" class="row_heading level0 row4" >time</th>
#       <td id="T_660fd_row4_col0" class="data row4 col0" >0.191</td>
#       <td id="T_660fd_row4_col1" class="data row4 col1" >0.172</td>
#       <td id="T_660fd_row4_col2" class="data row4 col2" >7</td>
#       <td id="T_660fd_row4_col3" class="data row4 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row5" class="row_heading level0 row5" >thing</th>
#       <td id="T_660fd_row5_col0" class="data row5 col0" >0.208</td>
#       <td id="T_660fd_row5_col1" class="data row5 col1" >0.510</td>
#       <td id="T_660fd_row5_col2" class="data row5 col2" >6</td>
#       <td id="T_660fd_row5_col3" class="data row5 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row6" class="row_heading level0 row6" >minute</th>
#       <td id="T_660fd_row6_col0" class="data row6 col0" >0.023</td>
#       <td id="T_660fd_row6_col1" class="data row6 col1" >0.056</td>
#       <td id="T_660fd_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_660fd_row6_col3" class="data row6 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row7" class="row_heading level0 row7" >source</th>
#       <td id="T_660fd_row7_col0" class="data row7 col0" >0.014</td>
#       <td id="T_660fd_row7_col1" class="data row7 col1" >0.030</td>
#       <td id="T_660fd_row7_col2" class="data row7 col2" >5</td>
#       <td id="T_660fd_row7_col3" class="data row7 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row8" class="row_heading level0 row8" >tool</th>
#       <td id="T_660fd_row8_col0" class="data row8 col0" >0.233</td>
#       <td id="T_660fd_row8_col1" class="data row8 col1" >0.435</td>
#       <td id="T_660fd_row8_col2" class="data row8 col2" >5</td>
#       <td id="T_660fd_row8_col3" class="data row8 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row9" class="row_heading level0 row9" >company</th>
#       <td id="T_660fd_row9_col0" class="data row9 col0" >0.250</td>
#       <td id="T_660fd_row9_col1" class="data row9 col1" >0.289</td>
#       <td id="T_660fd_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_660fd_row9_col3" class="data row9 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row10" class="row_heading level0 row10" >product</th>
#       <td id="T_660fd_row10_col0" class="data row10 col0" >0.200</td>
#       <td id="T_660fd_row10_col1" class="data row10 col1" >0.572</td>
#       <td id="T_660fd_row10_col2" class="data row10 col2" >4</td>
#       <td id="T_660fd_row10_col3" class="data row10 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_660fd_level0_row11" class="row_heading level0 row11" >task</th>
#       <td id="T_660fd_row11_col0" class="data row11 col0" >0.000</td>
#       <td id="T_660fd_row11_col1" class="data row11 col1" >0.000</td>
#       <td id="T_660fd_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_660fd_row11_col3" class="data row11 col3" >Positive</td>
#     </tr>
#   </tbody>
# </table>
# <div style='margin-bottom: 40px; border-bottom: 2px solid #eee;'></div>
#     <div style='border-left: 10px solid #0052CC; padding: 15px; background-color: #f8f9fa; margin: 20px 0;'>
#         <h2 style='color: #0052CC; margin: 0; font-family: sans-serif;'>STRATEGIC INTELLIGENCE: JIRA</h2>
#         <p style='margin: 5px 0 0 0; color: #666; font-style: italic;'>Binary Sentiment Aspect Distribution Analysis</p>
#     </div>
# <style type="text/css">
# #T_89da9 th {
#   background-color: #0052CC;
#   color: white;
#   font-family: sans-serif;
# }
# #T_89da9 td {
#   font-family: monospace;
# }
# #T_89da9_row0_col0, #T_89da9_row1_col0, #T_89da9_row2_col0, #T_89da9_row3_col0, #T_89da9_row4_col0, #T_89da9_row5_col0, #T_89da9_row7_col0, #T_89da9_row8_col0, #T_89da9_row9_col0, #T_89da9_row11_col0 {
#   font-weight: normal;
# }
# #T_89da9_row0_col3, #T_89da9_row1_col3, #T_89da9_row2_col3, #T_89da9_row3_col3, #T_89da9_row6_col3, #T_89da9_row7_col3, #T_89da9_row8_col3, #T_89da9_row10_col3, #T_89da9_row11_col3 {
#   color: #28a745;
#   font-weight: bold;
# }
# #T_89da9_row4_col3, #T_89da9_row5_col3, #T_89da9_row9_col3 {
#   color: #dc3545;
#   font-weight: bold;
# }
# #T_89da9_row6_col0, #T_89da9_row10_col0 {
#   font-weight: bold;
# }
# </style>
# <table id="T_89da9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_89da9_level0_col0" class="col_heading level0 col0" >avg_sentiment</th>
#       <th id="T_89da9_level0_col1" class="col_heading level0 col1" >sentiment_volatility</th>
#       <th id="T_89da9_level0_col2" class="col_heading level0 col2" >mention_frequency</th>
#       <th id="T_89da9_level0_col3" class="col_heading level0 col3" >final_label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89da9_level0_row0" class="row_heading level0 row0" >data</th>
#       <td id="T_89da9_row0_col0" class="data row0 col0" >0.097</td>
#       <td id="T_89da9_row0_col1" class="data row0 col1" >0.105</td>
#       <td id="T_89da9_row0_col2" class="data row0 col2" >12</td>
#       <td id="T_89da9_row0_col3" class="data row0 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row1" class="row_heading level0 row1" >source</th>
#       <td id="T_89da9_row1_col0" class="data row1 col0" >0.010</td>
#       <td id="T_89da9_row1_col1" class="data row1 col1" >0.026</td>
#       <td id="T_89da9_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_89da9_row1_col3" class="data row1 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row2" class="row_heading level0 row2" >startup</th>
#       <td id="T_89da9_row2_col0" class="data row2 col0" >0.000</td>
#       <td id="T_89da9_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_89da9_row2_col2" class="data row2 col2" >5</td>
#       <td id="T_89da9_row2_col3" class="data row2 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row3" class="row_heading level0 row3" >year</th>
#       <td id="T_89da9_row3_col0" class="data row3 col0" >0.020</td>
#       <td id="T_89da9_row3_col1" class="data row3 col1" >0.214</td>
#       <td id="T_89da9_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_89da9_row3_col3" class="data row3 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row4" class="row_heading level0 row4" >team</th>
#       <td id="T_89da9_row4_col0" class="data row4 col0" >-0.062</td>
#       <td id="T_89da9_row4_col1" class="data row4 col1" >0.161</td>
#       <td id="T_89da9_row4_col2" class="data row4 col2" >4</td>
#       <td id="T_89da9_row4_col3" class="data row4 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row5" class="row_heading level0 row5" >agent</th>
#       <td id="T_89da9_row5_col0" class="data row5 col0" >-0.125</td>
#       <td id="T_89da9_row5_col1" class="data row5 col1" >0.250</td>
#       <td id="T_89da9_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_89da9_row5_col3" class="data row5 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row6" class="row_heading level0 row6" >project</th>
#       <td id="T_89da9_row6_col0" class="data row6 col0" >0.522</td>
#       <td id="T_89da9_row6_col1" class="data row6 col1" >0.324</td>
#       <td id="T_89da9_row6_col2" class="data row6 col2" >3</td>
#       <td id="T_89da9_row6_col3" class="data row6 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row7" class="row_heading level0 row7" >github</th>
#       <td id="T_89da9_row7_col0" class="data row7 col0" >0.045</td>
#       <td id="T_89da9_row7_col1" class="data row7 col1" >0.079</td>
#       <td id="T_89da9_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_89da9_row7_col3" class="data row7 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row8" class="row_heading level0 row8" >email</th>
#       <td id="T_89da9_row8_col0" class="data row8 col0" >0.100</td>
#       <td id="T_89da9_row8_col1" class="data row8 col1" >0.000</td>
#       <td id="T_89da9_row8_col2" class="data row8 col2" >3</td>
#       <td id="T_89da9_row8_col3" class="data row8 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row9" class="row_heading level0 row9" >company</th>
#       <td id="T_89da9_row9_col0" class="data row9 col0" >-0.200</td>
#       <td id="T_89da9_row9_col1" class="data row9 col1" >0.346</td>
#       <td id="T_89da9_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_89da9_row9_col3" class="data row9 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row10" class="row_heading level0 row10" >thing</th>
#       <td id="T_89da9_row10_col0" class="data row10 col0" >0.667</td>
#       <td id="T_89da9_row10_col1" class="data row10 col1" >0.289</td>
#       <td id="T_89da9_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_89da9_row10_col3" class="data row10 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_89da9_level0_row11" class="row_heading level0 row11" >thread</th>
#       <td id="T_89da9_row11_col0" class="data row11 col0" >0.000</td>
#       <td id="T_89da9_row11_col1" class="data row11 col1" >0.000</td>
#       <td id="T_89da9_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_89da9_row11_col3" class="data row11 col3" >Positive</td>
#     </tr>
#   </tbody>
# </table>
# <div style='margin-bottom: 40px; border-bottom: 2px solid #eee;'></div>
#     <div style='border-left: 10px solid #7B68EE; padding: 15px; background-color: #f8f9fa; margin: 20px 0;'>
#         <h2 style='color: #7B68EE; margin: 0; font-family: sans-serif;'>STRATEGIC INTELLIGENCE: CLICKUP</h2>
#         <p style='margin: 5px 0 0 0; color: #666; font-style: italic;'>Binary Sentiment Aspect Distribution Analysis</p>
#     </div>
# <style type="text/css">
# #T_22d08 th {
#   background-color: #7B68EE;
#   color: white;
#   font-family: sans-serif;
# }
# #T_22d08 td {
#   font-family: monospace;
# }
# #T_22d08_row0_col0, #T_22d08_row1_col0, #T_22d08_row2_col0, #T_22d08_row3_col0, #T_22d08_row4_col0, #T_22d08_row6_col0, #T_22d08_row7_col0, #T_22d08_row8_col0, #T_22d08_row11_col0 {
#   font-weight: normal;
# }
# #T_22d08_row0_col3, #T_22d08_row1_col3, #T_22d08_row2_col3, #T_22d08_row3_col3, #T_22d08_row4_col3, #T_22d08_row5_col3, #T_22d08_row6_col3, #T_22d08_row7_col3, #T_22d08_row9_col3, #T_22d08_row11_col3 {
#   color: #28a745;
#   font-weight: bold;
# }
# #T_22d08_row5_col0, #T_22d08_row9_col0, #T_22d08_row10_col0 {
#   font-weight: bold;
# }
# #T_22d08_row8_col3, #T_22d08_row10_col3 {
#   color: #dc3545;
#   font-weight: bold;
# }
# </style>
# <table id="T_22d08" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22d08_level0_col0" class="col_heading level0 col0" >avg_sentiment</th>
#       <th id="T_22d08_level0_col1" class="col_heading level0 col1" >sentiment_volatility</th>
#       <th id="T_22d08_level0_col2" class="col_heading level0 col2" >mention_frequency</th>
#       <th id="T_22d08_level0_col3" class="col_heading level0 col3" >final_label</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >aspect</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22d08_level0_row0" class="row_heading level0 row0" >agent</th>
#       <td id="T_22d08_row0_col0" class="data row0 col0" >0.197</td>
#       <td id="T_22d08_row0_col1" class="data row0 col1" >0.165</td>
#       <td id="T_22d08_row0_col2" class="data row0 col2" >13</td>
#       <td id="T_22d08_row0_col3" class="data row0 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row1" class="row_heading level0 row1" >time</th>
#       <td id="T_22d08_row1_col0" class="data row1 col0" >0.113</td>
#       <td id="T_22d08_row1_col1" class="data row1 col1" >0.452</td>
#       <td id="T_22d08_row1_col2" class="data row1 col2" >10</td>
#       <td id="T_22d08_row1_col3" class="data row1 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row2" class="row_heading level0 row2" >work</th>
#       <td id="T_22d08_row2_col0" class="data row2 col0" >0.024</td>
#       <td id="T_22d08_row2_col1" class="data row2 col1" >0.142</td>
#       <td id="T_22d08_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_22d08_row2_col3" class="data row2 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row3" class="row_heading level0 row3" >week</th>
#       <td id="T_22d08_row3_col0" class="data row3 col0" >0.127</td>
#       <td id="T_22d08_row3_col1" class="data row3 col1" >0.217</td>
#       <td id="T_22d08_row3_col2" class="data row3 col2" >5</td>
#       <td id="T_22d08_row3_col3" class="data row3 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row4" class="row_heading level0 row4" >team</th>
#       <td id="T_22d08_row4_col0" class="data row4 col0" >0.120</td>
#       <td id="T_22d08_row4_col1" class="data row4 col1" >0.110</td>
#       <td id="T_22d08_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_22d08_row4_col3" class="data row4 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row5" class="row_heading level0 row5" >manager</th>
#       <td id="T_22d08_row5_col0" class="data row5 col0" >0.375</td>
#       <td id="T_22d08_row5_col1" class="data row5 col1" >0.479</td>
#       <td id="T_22d08_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_22d08_row5_col3" class="data row5 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row6" class="row_heading level0 row6" >system</th>
#       <td id="T_22d08_row6_col0" class="data row6 col0" >0.075</td>
#       <td id="T_22d08_row6_col1" class="data row6 col1" >0.250</td>
#       <td id="T_22d08_row6_col2" class="data row6 col2" >4</td>
#       <td id="T_22d08_row6_col3" class="data row6 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row7" class="row_heading level0 row7" >thing</th>
#       <td id="T_22d08_row7_col0" class="data row7 col0" >0.095</td>
#       <td id="T_22d08_row7_col1" class="data row7 col1" >0.746</td>
#       <td id="T_22d08_row7_col2" class="data row7 col2" >4</td>
#       <td id="T_22d08_row7_col3" class="data row7 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row8" class="row_heading level0 row8" >way</th>
#       <td id="T_22d08_row8_col0" class="data row8 col0" >-0.125</td>
#       <td id="T_22d08_row8_col1" class="data row8 col1" >0.250</td>
#       <td id="T_22d08_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_22d08_row8_col3" class="data row8 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row9" class="row_heading level0 row9" >tool</th>
#       <td id="T_22d08_row9_col0" class="data row9 col0" >0.321</td>
#       <td id="T_22d08_row9_col1" class="data row9 col1" >0.237</td>
#       <td id="T_22d08_row9_col2" class="data row9 col2" >4</td>
#       <td id="T_22d08_row9_col3" class="data row9 col3" >Positive</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row10" class="row_heading level0 row10" >software</th>
#       <td id="T_22d08_row10_col0" class="data row10 col0" >-0.333</td>
#       <td id="T_22d08_row10_col1" class="data row10 col1" >0.577</td>
#       <td id="T_22d08_row10_col2" class="data row10 col2" >3</td>
#       <td id="T_22d08_row10_col3" class="data row10 col3" >Negative</td>
#     </tr>
#     <tr>
#       <th id="T_22d08_level0_row11" class="row_heading level0 row11" >minute</th>
#       <td id="T_22d08_row11_col0" class="data row11 col0" >0.000</td>
#       <td id="T_22d08_row11_col1" class="data row11 col1" >0.000</td>
#       <td id="T_22d08_row11_col2" class="data row11 col2" >3</td>
#       <td id="T_22d08_row11_col3" class="data row11 col3" >Positive</td>
#     </tr>
#   </tbody>
# </table>
# <div style='margin-bottom: 40px; border-bottom: 2px solid #eee;'></div>
